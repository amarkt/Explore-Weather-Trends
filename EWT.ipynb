# %%
import pandas as pd                 
import matplotlib.pylab as plt

# %%
df = pd.read_csv('results.csv')

# %%
df.head()
# Out:
#    year   gat    cat
# 0  1796  8.27  25.03
# 1  1797  8.51  26.71
# 2  1798  8.67  24.29
# 3  1799  8.51  25.28
# 4  1800  8.48  25.21

# %%
moving_avg = df.rolling(150,center=False,on='cat').mean().dropna()

# %%
moving_avg
# Out:
#        year       gat    cat
# 149  1870.5  8.160467  24.78
# 150  1871.5  8.163200  25.47
# 151  1872.5  8.165133  25.72
# 152  1873.5  8.165667  25.45
# 153  1874.5  8.166200  25.60
# ..      ...       ...    ...
# 213  1934.5  8.563533  26.55
# 214  1935.5  8.575133  26.52
# 215  1936.5  8.586267  25.63
# 216  1937.5  8.599267  25.89
# 217  1938.5  8.609267  26.71
#
# [69 rows x 3 columns]

# %%
plt.plot(moving_avg['year'],moving_avg['gat'],label='Global')
plt.legend()
plt.xlabel('Years')
plt.ylabel('Temp')
plt.title("Global temp")
plt.show()

# %%
plt.plot(moving_avg.year,moving_avg.cat,label='New Delhi')
plt.xlabel('Years')
plt.ylabel('Temp')
plt.title('New Delhi Temp')
plt.show()

# %%
plt.plot(moving_avg.year,moving_avg.gat,label='Global')
plt.plot(moving_avg.year,moving_avg.cat,label='New Delhi')
plt.xlabel('Years')
plt.ylabel('Temp')
plt.title('Global vs New Delhi Temp over time')
plt.show()
